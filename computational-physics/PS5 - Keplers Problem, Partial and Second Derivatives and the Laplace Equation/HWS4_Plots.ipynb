# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path1 = '/Users/Austin/Desktop/PHY 40/Homework/4/PS4_1.txt'

x, y = np.loadtxt(file_path1, unpack = True) #Method to extract/import information from txt file  

# print(min(x), max(x))
# print(min(y), max(y))
    
        
plt.plot(x,y)
plt.xlabel('time (s)')
plt.ylabel('Energy (Joules)')
#plt.legend()
ax=plt.gca() #Allows for axis limits
ax.set(xlim=(min(x), max(x)), ylim=(1.01*min(y), .85*max(y)))
#ax.get_yaxis().get_major_formatter().set_scientific(False) #turning off scientif notation
#ax.get_yaxis().get_major_formatter().set_scientific(False) #turning off scientific notation
plt.grid()
plt.show()

# %%
file_path3 = '/Users/Austin/Desktop/PHY 40/Homework/4/PS4_3.txt'

x, y = np.loadtxt(file_path3, unpack = True) #Method to extract/import information from txt file  
    
        
plt.plot(x,y)
plt.xlabel('time (s)')
plt.ylabel('kg*m^2/s')
#ax1=plt.gca() #Allows for axis limits
#ax1.set(xlim=(min(x), max(x)), ylim=(min(y), max(y)))
plt.grid()
plt.show()
